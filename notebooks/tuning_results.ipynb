# %%
import pandas as pd

# %%
sho_gat_fixed_graph = pd.read_parquet("../output/sho/study_results_gat_fixed_graph/sho_gat_trials_df.parquet").sort_values("value")
sho_gcn_fixed_graph = pd.read_parquet("../output/sho/study_results_gcn_fixed_graph/sho_gat_trials_df.parquet").sort_values("value")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 sho_gat_fixed_graph = pd.read_parquet("../output/sho/study_results_gat_fixed_graph/sho_gat_trials_df.parquet").sort_values("value")
# ----> 2 sho_gcn_fixed_graph = pd.read_parquet("../output/sho/study_results_gcn_fixed_graph/sho_gat_trials_df.parquet").sort_values("value")
#
# File /dtu/3d-imaging-center/courses/conda/miniconda3/envs/env-02509/lib/python3.11/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
# ...

# %%
sho_gat_fixed_graph
# Out:
#      number     value             datetime_start          datetime_complete  \
# 182     182  1.369399 2025-03-18 16:47:30.640128 2025-03-18 16:48:57.135116
# 193     193  1.371921 2025-03-18 16:59:51.359665 2025-03-18 17:01:47.585248
# 93       93  1.445141 2025-03-18 14:36:22.923935 2025-03-18 14:39:31.675916
# 191     191  1.452152 2025-03-18 16:56:39.920263 2025-03-18 16:58:39.644817
# 199     199  1.452916 2025-03-18 17:06:14.538678 2025-03-18 17:07:49.583840
# ..      ...       ...                        ...                        ...
# 8         8  2.331090 2025-03-18 12:58:58.177749 2025-03-18 12:59:24.298828
# 6         6  2.367533 2025-03-18 12:58:19.412816 2025-03-18 12:58:47.028205
# 139     139  2.374264 2025-03-18 15:47:58.155099 2025-03-18 15:48:23.023017
# 0         0  2.405989 2025-03-18 12:53:38.476529 2025-03-18 12:53:56.579681
# 29       29  3.132194 2025-03-18 13:16:09.615754 2025-03-18 13:16:35.122110
#
# ...

# %%
sho_gcn_fixed_graph
# Out:
#      number     value             datetime_start          datetime_complete  \
# 184     184  1.520608 2025-03-19 01:28:18.390402 2025-03-19 01:29:14.488105
# 119     119  1.545497 2025-03-19 00:33:53.397389 2025-03-19 00:35:00.494100
# 118     118  1.546500 2025-03-19 00:32:42.767118 2025-03-19 00:33:53.396838
# 144     144  1.553902 2025-03-19 00:56:55.586414 2025-03-19 00:57:51.512877
# 127     127  1.558519 2025-03-19 00:41:24.136854 2025-03-19 00:42:27.300563
# ..      ...       ...                        ...                        ...
# 17       17  2.245937 2025-03-18 23:11:25.651589 2025-03-18 23:11:54.885457
# 9         9  2.272297 2025-03-18 23:04:38.402839 2025-03-18 23:05:01.164797
# 48       48  2.316375 2025-03-18 23:35:42.347378 2025-03-18 23:35:54.492666
# 188     188  2.744394 2025-03-19 01:30:53.403214 2025-03-19 01:31:08.562663
# 3         3  2.985722 2025-03-18 23:00:18.540547 2025-03-18 23:00:35.161163
#
# ...
